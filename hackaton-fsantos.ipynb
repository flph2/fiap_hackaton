# %% [markdown]
# # Hackaton Fiap

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set()

# %%
perfilCliente = pd.read_csv('data/Dataset-1.csv')
pageViews = pd.read_csv('data/Dataset-2.csv', )
catProdutos = pd.read_csv('data/Dataset-3.csv', )
# Out:
# /usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
perfilCliente = perfilCliente.head(500)

# %%
pageViews = pageViews.head(500)

# %%
catProdutos = catProdutos.head(500)

# %%
perfilCliente.sum()
# Out:
# Unnamed: 0                                                                  124750
# Id                               $2b$10$.DCvvJ9WSDpqVP2xXjeSPe9yBilu2JVQh2nFTHN...
# Idade                                                                        18563
# EstadoCivil                      MSSSSSSSSSSSSSSSSSSSSSSSSSSCCCCSSDDCCCSSSSSSSC...
# BillingCity                      AracruzTeresinaTeresinaTeresinaTeresinaTeresin...
# NivelConhecimentoAtual                                                        1112
# ScoreNivelConhecimento                                                        1154
# PerfilInvestidor                                                              1397
# RendaMensal                                                            3.90039e+06
# ValorPatrimonio                                                        1.32848e+08
# ScoreRisco                                                                    1393
# ...

# %%
pageViews.head()
# Out:
#    Unnamed: 0   Id             page_path  pageviews
# 0           0  NaN                   /s/          3
# 1           1  NaN                   /s/          8
# 2           2  NaN  /s/produtosprincipal          1
# 3           3  NaN                   /s/         21
# 4           4  NaN                   /s/          6

# %%
catProdutos.sum()
# Out:
# Unnamed: 0                                                                         124750
# AtivoDisponivel__c                                                                     28
# DescontoIR__c                                                                        8665
# DescricaoAtivo__c                       O Certificado de Dep�sito Banc�rio, de forma s...
# DescricaoCarencia__c                    No venc.No venc.No venc.No venc.No venc.No ven...
# DescricaoCotizacaoAplicacao__c          No diaNo diaNo diaNo diaNo diaNo diaNo diaNo d...
# DescricaoCotizacaoResgate__c            No diaNo diaNo diaNo diaNo diaNo diaNo diaNo d...
# DescricaoLiquidacaoAplicacao__c         No diaNo diaNo diaNo diaNo diaNo diaNo diaNo d...
# DescricaoLiquidacaoResgate__c           No diaNo diaNo diaNo diaNo diaNo diaNo diaNo d...
# DescricaoTributacao__c                  15%15%15%15%15%15%15%15%15%15%15%15%15%15%15%1...
# ...

# %% [markdown]
# ## Histograma de distribuição de clientes por perfil

# %%
plt.figure()
plt.hist(perfilCliente.PerfilInvestidor)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure()
pc = perfilCliente.FamiliaCarteira
pc.dropna(inplace=True)
plt.hist(pc)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure()
plt.hist(perfilCliente.Rentabilidade12Meses)
plt.show
# Out:
# /usr/local/lib64/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib64/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure()
plt.hist(perfilCliente.ValorInvestidoAtual)
plt.show
# Out:
# /usr/local/lib64/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib64/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure()
plt.hist(perfilCliente.RendaMensal)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
perfilCliente["TaxaClienteIPCA"] = perfilCliente["TaxaCliente"] < 15
perfilCliente["TaxaClienteCDI"] = perfilCliente["TaxaCliente"] > 70

# %%
plt.figure(figsize=(10, 8))
corr = perfilCliente.corr()
sns.heatmap(corr)

# %%
sns.set(style="white")

# Generate a large random dataset
rs = np.random.RandomState(33)


# Compute the correlation matrix
corr = perfilCliente.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
